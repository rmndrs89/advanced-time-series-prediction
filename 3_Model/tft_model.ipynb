# %% [markdown]
# ## Install Libraries

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import os
import torch
from torch.utils.data import Dataset
import torch.nn as nn
from torch.utils.data import DataLoader

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, classification_report, ConfusionMatrixDisplay

# %% [markdown]
# ## Load Train and Test Data

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATASET_PATH = Path("/kaggle/input/tds-fog-windowed-dataset/tdcsfog")
TRAIN_PATH = DATASET_PATH / "train"
TEST_PATH = DATASET_PATH / "test"

# %%
file_path = '/kaggle/input/tds-fog-windowed-dataset/tdcsfog/test/009ee11563_0000.npy'

with open(file_path, "rb") as infile:
        arr = np.load(infile)

print(arr.shape)
arr[1]
# # Extract the accelerometer data as the input features
# features = arr[:, 1:4]

# # Extract the labels
# labels = arr[:, 4:]
# labels = np.max(labels, axis=-1)
# return features, np.any(labels).astype(float)
# Out:
# (1280, 7)
# array([ 1.        , -9.42509672,  0.7682455 , -1.75057992,  0.        ,
#         0.        ,  0.        ])

# %%
import os
import numpy as np
import torch
from torch.utils.data import Dataset



def load_windowed_data_with_label(folder_path, rolling_window=5):
    X = []
    y = []

    for filename in os.listdir(folder_path):
        if filename.endswith(".npy"):
            arr = np.load(os.path.join(folder_path, filename))  # shape: (window_len, 7)

            features = arr[:, 1:4]    # 3 original features (acc_x, acc_y, acc_z)
            labels = arr[:, 4:]      # last 3 columns = FoG levels

            # Convert to DataFrame for rolling
            df_feat = pd.DataFrame(features, columns=['acc_x', 'acc_y', 'acc_z'])

            # Add rolling average columns (window=5)
            for col in df_feat.columns:
                df_feat[f'{col}_avg'] = df_feat[col].rolling(window=rolling_window, min_periods=1).mean()

            features_with_avg = df_feat.to_numpy()  # shape: (1280, 6)

            # Create label: if any row in any of the 3 FoG columns has 1
            label = int(np.any(labels > 0))

            X.append(features_with_avg)
            y.append(label)

    return np.array(X), np.array(y)

# %%
X, y = load_windowed_data_with_label(TRAIN_PATH)



from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
X_test, y_test = load_windowed_data_with_label(TEST_PATH)

# %%
from torch.utils.data import TensorDataset, DataLoader

X_tensor_train = torch.tensor(X_train, dtype=torch.float32)
y_tensor_train = torch.tensor(y_train, dtype=torch.float32)

dataset_train = TensorDataset(X_tensor_train, y_tensor_train)
train_loader = DataLoader(dataset_train, batch_size=32, shuffle=False)

#--------------------------------------

X_tensor_val = torch.tensor(X_val, dtype=torch.float32)
y_tensor_val = torch.tensor(y_val, dtype=torch.float32)

dataset_val = TensorDataset(X_tensor_val, y_tensor_val)
val_loader = DataLoader(dataset_val, batch_size=32, shuffle=False)

#--------------------------------------

X_tensor_test = torch.tensor(X_test, dtype=torch.float32)
y_tensor_test = torch.tensor(y_test, dtype=torch.float32)

dataset_test = TensorDataset(X_tensor_test, y_tensor_test)
test_loader = DataLoader(dataset_test, batch_size=32, shuffle=False)

# %%
print(X_train.shape)
print(y_train.shape)
print('-'*20)
print(X_val.shape)
print('-'*20)
print(X_test.shape)
print('-'*20)
# Out:
# (3308, 1280, 6)
# (3308,)
# --------------------
# (828, 1280, 6)
# --------------------
# (960, 1280, 6)
# --------------------

# %%
print("Train label distribution:", torch.unique(y_tensor_train, return_counts=True))
print(torch.unique(y_tensor_train))  # must be tensor([0., 1.])
print(y_tensor_val.dtype)          # must be torch.float32
# Out:
# Train label distribution: (tensor([0., 1.]), tensor([1657, 1651]))
# tensor([0., 1.])
# torch.float32

# %% [markdown]
# ## GRU Model

# %%
import torch
import torch.nn as nn

class DeepGRUModel(nn.Module):
    def __init__(self, input_size=6, hidden_size=128, num_layers=3, dropout=0.3):
        super().__init__()

        self.gru = nn.GRU(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True,
            dropout=dropout,
            bidirectional=True  # optional but effective
        )

        self.classifier = nn.Sequential(
            nn.Linear(hidden_size * 2, 128),  # *2 due to bidirectional
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 1)  # output raw logits
        )

    def forward(self, x):
        out, _ = self.gru(x)              # out: (B, T, 2*H)
        out = out[:, -1, :]               # last time step: (B, 2*H)
        return self.classifier(out)       # logits → use BCEWithLogitsLoss

# %%
class TemporalFusionTransformer(nn.Module):
    def __init__(self, input_size, hidden_size=64, num_heads=4, dropout=0.1):
        super().__init__()
        
        self.input_proj = nn.Linear(input_size, hidden_size)
        self.pos_enc = nn.Parameter(torch.randn(1, 1280, hidden_size))  # assumes fixed 1280 sequence length

        self.encoder = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(
                d_model=hidden_size,
                nhead=num_heads,
                dim_feedforward=hidden_size * 4,
                dropout=dropout,
                activation='relu',
                batch_first=True
            ),
            num_layers=2
        )

        self.fc = nn.Sequential(
            nn.Linear(hidden_size, 64),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(64, 1)  # output logits
        )

    def forward(self, x):
        """
        x: (batch_size, seq_len, input_size)
        """
        x = self.input_proj(x) + self.pos_enc[:, :x.size(1), :]
        x = self.encoder(x)
        out = x[:, -1, :]  # use last time step
        return self.fc(out)  # logits

# %% [markdown]
# Training Loop

# %%
def train_model(model, train_loader, val_loader, epochs=100, lr=1e-3):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = nn.BCEWithLogitsLoss()
  # Because model output is sigmoid
    train_losses = []
    val_accuracies = []
    val_precisions = []
    val_recalls = []
    val_f1_scores = []
    val_aucs = []
    
    for epoch in range(epochs):
        model.train()
        total_loss = 0

        for xb, yb in train_loader:
            xb = xb.to(device)
            yb = yb.to(device).unsqueeze(1)  # (B,) → (B, 1)

            pred = model(xb)
            loss = criterion(pred, yb)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        avg_loss = total_loss / len(train_loader)
        print(f"Epoch {epoch+1}, Train Loss: {avg_loss:.4f}")

        # --------- Validation Phase ---------
        model.eval()
        all_preds = []
        all_labels = []

        with torch.no_grad():
            for xb, yb in val_loader:
                xb = xb.to(device)
                yb = yb.to(device).unsqueeze(1)

                logits = model(xb)
                probs = torch.sigmoid(logits)
                all_preds.append(probs.cpu())
                all_labels.append(yb.cpu())

        y_prob = torch.cat(all_preds)
        y_true = torch.cat(all_labels)
        y_pred = (y_prob > 0.5).float()

        acc = (y_pred == y_true).float().mean()
        prec = precision_score(y_true, y_pred, zero_division=0)
        rec = recall_score(y_true, y_pred, zero_division=0)
        f1 = f1_score(y_true, y_pred, zero_division=0)
        auc = roc_auc_score(y_true, y_prob)

        # Print results
        print(f"Validation Accuracy:  {acc:.4f}")
        print(f"Precision:            {prec:.4f}")
        print(f"Recall:               {rec:.4f}")
        print(f"F1 Score:             {f1:.4f}")
        print(f"ROC AUC Score:        {auc:.4f}")
        print('---'*20)
        train_losses.append(avg_loss)
        val_accuracies.append(acc)
        val_precisions.append(prec)
        val_recalls.append(rec)
        val_f1_scores.append(f1)
        val_aucs.append(auc)

# %%
# rnn_model = RNNModel()
GRU_model = DeepGRUModel(input_size=6, hidden_size=128, num_layers=3)
train_model(GRU_model, train_loader, val_loader)
# Out:
# Epoch 1, Train Loss: 0.6513
# Validation Accuracy:  0.6329
# Precision:            0.7300
# Recall:               0.4189
# F1 Score:             0.5323
# ROC AUC Score:        0.6684
# ------------------------------------------------------------
# Epoch 2, Train Loss: 0.6085
# Validation Accuracy:  0.6546
# Precision:            0.8191
# Recall:               0.3947
# F1 Score:             0.5327
# ROC AUC Score:        0.7144
# ------------------------------------------------------------
# Epoch 3, Train Loss: 0.5919
# Validation Accuracy:  0.6800
# Precision:            0.7517
# Recall:               0.5351
# F1 Score:             0.6252
# ROC AUC Score:        0.7554
# ------------------------------------------------------------
# Epoch 4, Train Loss: 0.5490
# Validation Accuracy:  0.7246
# Precision:            0.7033
# Recall:               0.7748
# F1 Score:             0.7373
# ROC AUC Score:        0.8140
# ------------------------------------------------------------
# Epoch 5, Train Loss: 0.4795
# Validation Accuracy:  0.7899
# Precision:            0.7786
# Recall:               0.8087
# F1 Score:             0.7933
# ROC AUC Score:        0.8671
# ------------------------------------------------------------
# Epoch 6, Train Loss: 0.4217
# Validation Accuracy:  0.7899
# Precision:            0.7773
# Recall:               0.8111
# F1 Score:             0.7938
# ROC AUC Score:        0.8759
# ------------------------------------------------------------
# Epoch 7, Train Loss: 0.3955
# Validation Accuracy:  0.8176
# Precision:            0.8291
# Recall:               0.7990
# F1 Score:             0.8138
# ROC AUC Score:        0.8924
# ------------------------------------------------------------
# Epoch 8, Train Loss: 0.3770
# Validation Accuracy:  0.8345
# Precision:            0.8350
# Recall:               0.8329
# F1 Score:             0.8339
# ROC AUC Score:        0.9125
# ------------------------------------------------------------
# Epoch 9, Train Loss: 0.3526
# Validation Accuracy:  0.8080
# Precision:            0.8024
# Recall:               0.8160
# F1 Score:             0.8091
# ROC AUC Score:        0.8951
# ------------------------------------------------------------
# Epoch 10, Train Loss: 0.3667
# Validation Accuracy:  0.8382
# Precision:            0.8642
# Recall:               0.8015
# F1 Score:             0.8317
# ROC AUC Score:        0.9115
# ------------------------------------------------------------
# Epoch 11, Train Loss: 0.3347
# Validation Accuracy:  0.8164
# Precision:            0.7946
# Recall:               0.8523
# F1 Score:             0.8224
# ROC AUC Score:        0.9045
# ------------------------------------------------------------
# Epoch 12, Train Loss: 0.3199
# Validation Accuracy:  0.8285
# Precision:            0.8203
# Recall:               0.8402
# F1 Score:             0.8301
# ROC AUC Score:        0.9118
# ------------------------------------------------------------
# Epoch 13, Train Loss: 0.3812
# Validation Accuracy:  0.8249
# Precision:            0.8526
# Recall:               0.7845
# F1 Score:             0.8172
# ROC AUC Score:        0.9020
# ------------------------------------------------------------
# Epoch 14, Train Loss: 0.3731
# Validation Accuracy:  0.7874
# Precision:            0.7394
# Recall:               0.8862
# F1 Score:             0.8062
# ROC AUC Score:        0.9018
# ------------------------------------------------------------
# Epoch 15, Train Loss: 0.3567
# Validation Accuracy:  0.8273
# Precision:            0.8629
# Recall:               0.7772
# F1 Score:             0.8178
# ROC AUC Score:        0.8964
# ------------------------------------------------------------
# Epoch 16, Train Loss: 0.3650
# Validation Accuracy:  0.8297
# Precision:            0.8417
# Recall:               0.8111
# F1 Score:             0.8261
# ROC AUC Score:        0.9061
# ------------------------------------------------------------
# Epoch 17, Train Loss: 0.3367
# Validation Accuracy:  0.8188
# Precision:            0.7968
# Recall:               0.8547
# F1 Score:             0.8248
# ROC AUC Score:        0.9106
# ------------------------------------------------------------
# Epoch 18, Train Loss: 0.3471
# Validation Accuracy:  0.8297
# Precision:            0.8696
# Recall:               0.7748
# F1 Score:             0.8195
# ROC AUC Score:        0.9094
# ------------------------------------------------------------
# Epoch 19, Train Loss: 0.3310
# Validation Accuracy:  0.8382
# Precision:            0.8207
# Recall:               0.8644
# F1 Score:             0.8420
# ROC AUC Score:        0.9142
# ------------------------------------------------------------
# Epoch 20, Train Loss: 0.3166
# Validation Accuracy:  0.8116
# Precision:            0.7995
# Recall:               0.8305
# F1 Score:             0.8147
# ROC AUC Score:        0.9034
# ------------------------------------------------------------
# Epoch 21, Train Loss: 0.3445
# Validation Accuracy:  0.8237
# Precision:            0.7960
# Recall:               0.8692
# F1 Score:             0.8310
# ROC AUC Score:        0.9125
# ------------------------------------------------------------
# Epoch 22, Train Loss: 0.3038
# Validation Accuracy:  0.8418
# Precision:            0.8310
# Recall:               0.8571
# F1 Score:             0.8439
# ROC AUC Score:        0.9189
# ------------------------------------------------------------
# Epoch 23, Train Loss: 0.3034
# Validation Accuracy:  0.7210
# Precision:            0.6602
# Recall:               0.9080
# F1 Score:             0.7645
# ROC AUC Score:        0.8689
# ------------------------------------------------------------
# Epoch 24, Train Loss: 0.5962
# Validation Accuracy:  0.7669
# Precision:            0.7546
# Recall:               0.7893
# F1 Score:             0.7716
# ROC AUC Score:        0.8424
# ------------------------------------------------------------
# Epoch 25, Train Loss: 0.4608
# Validation Accuracy:  0.8043
# Precision:            0.8724
# Recall:               0.7119
# F1 Score:             0.7840
# ROC AUC Score:        0.8790
# ------------------------------------------------------------
# Epoch 26, Train Loss: 0.4046
# Validation Accuracy:  0.8019
# Precision:            0.9770
# Recall:               0.6174
# F1 Score:             0.7567
# ROC AUC Score:        0.8940
# ------------------------------------------------------------
# Epoch 27, Train Loss: 0.3850
# Validation Accuracy:  0.8249
# Precision:            0.8785
# Recall:               0.7530
# F1 Score:             0.8110
# ROC AUC Score:        0.8959
# ------------------------------------------------------------
# Epoch 28, Train Loss: 0.3690
# Validation Accuracy:  0.8273
# Precision:            0.9018
# Recall:               0.7337
# F1 Score:             0.8091
# ROC AUC Score:        0.9036
# ------------------------------------------------------------
# Epoch 29, Train Loss: 0.3598
# Validation Accuracy:  0.8273
# Precision:            0.8426
# Recall:               0.8039
# F1 Score:             0.8228
# ROC AUC Score:        0.8987
# ------------------------------------------------------------
# Epoch 30, Train Loss: 0.3444
# Validation Accuracy:  0.8237
# Precision:            0.8432
# Recall:               0.7942
# F1 Score:             0.8180
# ROC AUC Score:        0.9018
# ------------------------------------------------------------
# Epoch 31, Train Loss: 0.3376
# Validation Accuracy:  0.8225
# Precision:            0.8519
# Recall:               0.7797
# F1 Score:             0.8142
# ROC AUC Score:        0.9060
# ------------------------------------------------------------
# Epoch 32, Train Loss: 0.3377
# Validation Accuracy:  0.8285
# Precision:            0.8297
# Recall:               0.8257
# F1 Score:             0.8277
# ROC AUC Score:        0.9095
# ------------------------------------------------------------
# Epoch 33, Train Loss: 0.3240
# Validation Accuracy:  0.8225
# Precision:            0.8260
# Recall:               0.8160
# F1 Score:             0.8210
# ROC AUC Score:        0.9133
# ------------------------------------------------------------
# Epoch 34, Train Loss: 0.3282
# Validation Accuracy:  0.8406
# Precision:            0.8892
# Recall:               0.7772
# F1 Score:             0.8295
# ROC AUC Score:        0.9078
# ------------------------------------------------------------
# Epoch 35, Train Loss: 0.3196
# Validation Accuracy:  0.8188
# Precision:            0.8329
# Recall:               0.7966
# F1 Score:             0.8144
# ROC AUC Score:        0.9065
# ------------------------------------------------------------
# Epoch 36, Train Loss: 0.3151
# Validation Accuracy:  0.8237
# Precision:            0.8719
# Recall:               0.7579
# F1 Score:             0.8109
# ROC AUC Score:        0.9008
# ------------------------------------------------------------
# Epoch 37, Train Loss: 0.3021
# Validation Accuracy:  0.8261
# Precision:            0.8422
# Recall:               0.8015
# F1 Score:             0.8213
# ROC AUC Score:        0.9001
# ------------------------------------------------------------
# Epoch 38, Train Loss: 0.2976
# Validation Accuracy:  0.8490
# Precision:            0.9000
# Recall:               0.7845
# F1 Score:             0.8383
# ROC AUC Score:        0.9133
# ------------------------------------------------------------
# Epoch 39, Train Loss: 0.2910
# Validation Accuracy:  0.8466
# Precision:            0.8522
# Recall:               0.8378
# F1 Score:             0.8449
# ROC AUC Score:        0.9128
# ------------------------------------------------------------
# Epoch 40, Train Loss: 0.3130
# Validation Accuracy:  0.8490
# Precision:            0.8956
# Recall:               0.7893
# F1 Score:             0.8391
# ROC AUC Score:        0.9171
# ------------------------------------------------------------
# Epoch 41, Train Loss: 0.2810
# Validation Accuracy:  0.8406
# Precision:            0.8418
# Recall:               0.8378
# F1 Score:             0.8398
# ROC AUC Score:        0.9180
# ------------------------------------------------------------
# Epoch 42, Train Loss: 0.2805
# Validation Accuracy:  0.8370
# Precision:            0.8458
# Recall:               0.8232
# F1 Score:             0.8344
# ROC AUC Score:        0.9177
# ------------------------------------------------------------
# Epoch 43, Train Loss: 0.2709
# Validation Accuracy:  0.8345
# Precision:            0.8467
# Recall:               0.8160
# F1 Score:             0.8311
# ROC AUC Score:        0.9184
# ------------------------------------------------------------
# Epoch 44, Train Loss: 0.2765
# Validation Accuracy:  0.8406
# Precision:            0.8435
# Recall:               0.8354
# F1 Score:             0.8394
# ROC AUC Score:        0.9187
# ------------------------------------------------------------
# Epoch 45, Train Loss: 0.2761
# Validation Accuracy:  0.8563
# Precision:            0.8910
# Recall:               0.8111
# F1 Score:             0.8492
# ROC AUC Score:        0.9146
# ------------------------------------------------------------
# Epoch 46, Train Loss: 0.5288
# Validation Accuracy:  0.7271
# Precision:            0.6866
# Recall:               0.8329
# F1 Score:             0.7527
# ROC AUC Score:        0.8303
# ------------------------------------------------------------
# Epoch 47, Train Loss: 0.4225
# Validation Accuracy:  0.7778
# Precision:            0.7800
# Recall:               0.7724
# F1 Score:             0.7762
# ROC AUC Score:        0.8677
# ------------------------------------------------------------
# Epoch 48, Train Loss: 0.3718
# Validation Accuracy:  0.8043
# Precision:            0.8177
# Recall:               0.7821
# F1 Score:             0.7995
# ROC AUC Score:        0.8892
# ------------------------------------------------------------
# Epoch 49, Train Loss: 0.3366
# Validation Accuracy:  0.7983
# Precision:            0.7929
# Recall:               0.8063
# F1 Score:             0.7995
# ROC AUC Score:        0.8899
# ------------------------------------------------------------
# Epoch 50, Train Loss: 0.3244
# Validation Accuracy:  0.7995
# Precision:            0.7679
# Recall:               0.8571
# F1 Score:             0.8101
# ROC AUC Score:        0.9028
# ------------------------------------------------------------
# Epoch 51, Train Loss: 0.3103
# Validation Accuracy:  0.8116
# Precision:            0.7968
# Recall:               0.8354
# F1 Score:             0.8156
# ROC AUC Score:        0.9067
# ------------------------------------------------------------
# Epoch 52, Train Loss: 0.3304
# Validation Accuracy:  0.7971
# Precision:            0.7634
# Recall:               0.8596
# F1 Score:             0.8087
# ROC AUC Score:        0.8982
# ------------------------------------------------------------
# Epoch 53, Train Loss: 0.3027
# Validation Accuracy:  0.8297
# Precision:            0.8400
# Recall:               0.8136
# F1 Score:             0.8266
# ROC AUC Score:        0.9088
# ------------------------------------------------------------
# Epoch 54, Train Loss: 0.2855
# Validation Accuracy:  0.8080
# Precision:            0.7940
# Recall:               0.8305
# F1 Score:             0.8118
# ROC AUC Score:        0.9042
# ------------------------------------------------------------
# Epoch 55, Train Loss: 0.2730
# Validation Accuracy:  0.8285
# Precision:            0.8101
# Recall:               0.8571
# F1 Score:             0.8329
# ROC AUC Score:        0.9108
# ------------------------------------------------------------
# Epoch 56, Train Loss: 0.2519
# Validation Accuracy:  0.8285
# Precision:            0.8234
# Recall:               0.8354
# F1 Score:             0.8293
# ROC AUC Score:        0.9144
# ------------------------------------------------------------
# Epoch 57, Train Loss: 0.2576
# Validation Accuracy:  0.8273
# Precision:            0.8342
# Recall:               0.8160
# F1 Score:             0.8250
# ROC AUC Score:        0.9071
# ------------------------------------------------------------
# Epoch 58, Train Loss: 0.2571
# Validation Accuracy:  0.8394
# Precision:            0.8684
# Recall:               0.7990
# F1 Score:             0.8323
# ROC AUC Score:        0.9072
# ------------------------------------------------------------
# Epoch 59, Train Loss: 0.2478
# Validation Accuracy:  0.8104
# Precision:            0.8005
# Recall:               0.8257
# F1 Score:             0.8129
# ROC AUC Score:        0.9029
# ------------------------------------------------------------
# Epoch 60, Train Loss: 0.2457
# Validation Accuracy:  0.8418
# Precision:            0.8422
# Recall:               0.8402
# F1 Score:             0.8412
# ROC AUC Score:        0.9093
# ------------------------------------------------------------
# Epoch 61, Train Loss: 0.2272
# Validation Accuracy:  0.8333
# Precision:            0.8412
# Recall:               0.8208
# F1 Score:             0.8309
# ROC AUC Score:        0.9150
# ------------------------------------------------------------
# Epoch 62, Train Loss: 0.2341
# Validation Accuracy:  0.8466
# Precision:            0.8783
# Recall:               0.8039
# F1 Score:             0.8394
# ROC AUC Score:        0.9110
# ------------------------------------------------------------
# Epoch 63, Train Loss: 0.2287
# Validation Accuracy:  0.8285
# Precision:            0.8101
# Recall:               0.8571
# F1 Score:             0.8329
# ROC AUC Score:        0.9130
# ------------------------------------------------------------
# Epoch 64, Train Loss: 0.2171
# Validation Accuracy:  0.8394
# Precision:            0.8302
# Recall:               0.8523
# F1 Score:             0.8411
# ROC AUC Score:        0.9105
# ------------------------------------------------------------
# Epoch 65, Train Loss: 0.2081
# Validation Accuracy:  0.8345
# Precision:            0.8317
# Recall:               0.8378
# F1 Score:             0.8347
# ROC AUC Score:        0.9086
# ------------------------------------------------------------
# Epoch 66, Train Loss: 0.1936
# Validation Accuracy:  0.8394
# Precision:            0.8846
# Recall:               0.7797
# F1 Score:             0.8288
# ROC AUC Score:        0.9115
# ------------------------------------------------------------
# Epoch 67, Train Loss: 0.1995
# Validation Accuracy:  0.8309
# Precision:            0.8081
# Recall:               0.8668
# F1 Score:             0.8364
# ROC AUC Score:        0.9136
# ------------------------------------------------------------
# Epoch 68, Train Loss: 0.1941
# Validation Accuracy:  0.8237
# Precision:            0.7987
# Recall:               0.8644
# F1 Score:             0.8302
# ROC AUC Score:        0.9088
# ------------------------------------------------------------
# Epoch 69, Train Loss: 0.1939
# Validation Accuracy:  0.8140
# Precision:            0.7785
# Recall:               0.8765
# F1 Score:             0.8246
# ROC AUC Score:        0.9158
# ------------------------------------------------------------
# Epoch 70, Train Loss: 0.1611
# Validation Accuracy:  0.7971
# Precision:            0.7526
# Recall:               0.8838
# F1 Score:             0.8129
# ROC AUC Score:        0.9088
# ------------------------------------------------------------
# Epoch 71, Train Loss: 0.1775
# Validation Accuracy:  0.8092
# Precision:            0.7673
# Recall:               0.8862
# F1 Score:             0.8225
# ROC AUC Score:        0.9105
# ------------------------------------------------------------
# Epoch 72, Train Loss: 0.1801
# Validation Accuracy:  0.8104
# Precision:            0.7689
# Recall:               0.8862
# F1 Score:             0.8234
# ROC AUC Score:        0.9127
# ------------------------------------------------------------
# Epoch 73, Train Loss: 0.1637
# Validation Accuracy:  0.8357
# Precision:            0.8155
# Recall:               0.8668
# F1 Score:             0.8404
# ROC AUC Score:        0.9153
# ------------------------------------------------------------
# Epoch 74, Train Loss: 0.1510
# Validation Accuracy:  0.8043
# Precision:            0.7546
# Recall:               0.9007
# F1 Score:             0.8212
# ROC AUC Score:        0.9112
# ------------------------------------------------------------
# Epoch 75, Train Loss: 0.1558
# Validation Accuracy:  0.8200
# Precision:            0.8099
# Recall:               0.8354
# F1 Score:             0.8224
# ROC AUC Score:        0.9083
# ------------------------------------------------------------
# Epoch 76, Train Loss: 0.1675
# Validation Accuracy:  0.8273
# Precision:            0.7961
# Recall:               0.8789
# F1 Score:             0.8354
# ROC AUC Score:        0.9150
# ------------------------------------------------------------
# Epoch 77, Train Loss: 0.1352
# Validation Accuracy:  0.8406
# Precision:            0.8306
# Recall:               0.8547
# F1 Score:             0.8425
# ROC AUC Score:        0.9147
# ------------------------------------------------------------
# Epoch 78, Train Loss: 0.1363
# Validation Accuracy:  0.8370
# Precision:            0.8325
# Recall:               0.8426
# F1 Score:             0.8375
# ROC AUC Score:        0.9146
# ------------------------------------------------------------
# Epoch 79, Train Loss: 0.1434
# Validation Accuracy:  0.8164
# Precision:            0.7946
# Recall:               0.8523
# F1 Score:             0.8224
# ROC AUC Score:        0.9111
# ------------------------------------------------------------
# Epoch 80, Train Loss: 0.1647
# Validation Accuracy:  0.8321
# Precision:            0.8644
# Recall:               0.7869
# F1 Score:             0.8238
# ROC AUC Score:        0.9002
# ------------------------------------------------------------
# Epoch 81, Train Loss: 0.1251
# Validation Accuracy:  0.8345
# Precision:            0.8538
# Recall:               0.8063
# F1 Score:             0.8294
# ROC AUC Score:        0.9123
# ------------------------------------------------------------
# Epoch 82, Train Loss: 0.1486
# Validation Accuracy:  0.8418
# Precision:            0.8874
# Recall:               0.7821
# F1 Score:             0.8314
# ROC AUC Score:        0.9027
# ------------------------------------------------------------
# Epoch 83, Train Loss: 0.1519
# Validation Accuracy:  0.8394
# Precision:            0.8571
# Recall:               0.8136
# F1 Score:             0.8348
# ROC AUC Score:        0.9140
# ------------------------------------------------------------
# Epoch 84, Train Loss: 0.1300
# Validation Accuracy:  0.8164
# Precision:            0.8145
# Recall:               0.8184
# F1 Score:             0.8164
# ROC AUC Score:        0.9025
# ------------------------------------------------------------
# Epoch 85, Train Loss: 0.1267
# Validation Accuracy:  0.8213
# Precision:            0.8089
# Recall:               0.8402
# F1 Score:             0.8242
# ROC AUC Score:        0.9104
# ------------------------------------------------------------
# Epoch 86, Train Loss: 0.1039
# Validation Accuracy:  0.8140
# Precision:            0.7977
# Recall:               0.8402
# F1 Score:             0.8184
# ROC AUC Score:        0.9027
# ------------------------------------------------------------
# Epoch 87, Train Loss: 0.1166
# Validation Accuracy:  0.8140
# Precision:            0.7809
# Recall:               0.8717
# F1 Score:             0.8238
# ROC AUC Score:        0.9124
# ------------------------------------------------------------
# Epoch 88, Train Loss: 0.1249
# Validation Accuracy:  0.8466
# Precision:            0.8389
# Recall:               0.8571
# F1 Score:             0.8479
# ROC AUC Score:        0.9138
# ------------------------------------------------------------
# Epoch 89, Train Loss: 0.1263
# Validation Accuracy:  0.8104
# Precision:            0.7735
# Recall:               0.8765
# F1 Score:             0.8218
# ROC AUC Score:        0.9082
# ------------------------------------------------------------
# Epoch 90, Train Loss: 0.1036
# Validation Accuracy:  0.8104
# Precision:            0.7844
# Recall:               0.8547
# F1 Score:             0.8181
# ROC AUC Score:        0.9024
# ------------------------------------------------------------
# Epoch 91, Train Loss: 0.1008
# Validation Accuracy:  0.8164
# Precision:            0.7856
# Recall:               0.8692
# F1 Score:             0.8253
# ROC AUC Score:        0.9166
# ------------------------------------------------------------
# Epoch 92, Train Loss: 0.0914
# Validation Accuracy:  0.8116
# Precision:            0.7752
# Recall:               0.8765
# F1 Score:             0.8227
# ROC AUC Score:        0.9088
# ------------------------------------------------------------
# Epoch 93, Train Loss: 0.0887
# Validation Accuracy:  0.8213
# Precision:            0.7825
# Recall:               0.8886
# F1 Score:             0.8322
# ROC AUC Score:        0.9182
# ------------------------------------------------------------
# Epoch 94, Train Loss: 0.0875
# Validation Accuracy:  0.8092
# Precision:            0.7673
# Recall:               0.8862
# F1 Score:             0.8225
# ROC AUC Score:        0.9104
# ------------------------------------------------------------
# Epoch 95, Train Loss: 0.0860
# Validation Accuracy:  0.8237
# Precision:            0.8027
# Recall:               0.8571
# F1 Score:             0.8290
# ROC AUC Score:        0.9050
# ------------------------------------------------------------
# Epoch 96, Train Loss: 0.0928
# Validation Accuracy:  0.7971
# Precision:            0.7526
# Recall:               0.8838
# F1 Score:             0.8129
# ROC AUC Score:        0.9057
# ------------------------------------------------------------
# Epoch 97, Train Loss: 0.0890
# Validation Accuracy:  0.8152
# Precision:            0.7766
# Recall:               0.8838
# F1 Score:             0.8267
# ROC AUC Score:        0.9127
# ------------------------------------------------------------
# Epoch 98, Train Loss: 0.0769
# Validation Accuracy:  0.8345
# Precision:            0.8301
# Recall:               0.8402
# F1 Score:             0.8351
# ROC AUC Score:        0.9078
# ------------------------------------------------------------
# Epoch 99, Train Loss: 0.0857
# Validation Accuracy:  0.7862
# Precision:            0.7379
# Recall:               0.8862
# F1 Score:             0.8053
# ROC AUC Score:        0.9050
# ------------------------------------------------------------
# Epoch 100, Train Loss: 0.0688
# Validation Accuracy:  0.8261
# Precision:            0.8050
# Recall:               0.8596
# F1 Score:             0.8314
# ROC AUC Score:        0.9141
# ------------------------------------------------------------

# %%
tft_model = TemporalFusionTransformer(input_size=6)  # 6 features per timestep
train_model(tft_model, train_loader, val_loader, epochs=100)
# Out:
# Epoch 1, Train Loss: 0.6099
# Validation Accuracy:  0.6618
# Precision:            0.6161
# Recall:               0.8547
# F1 Score:             0.7160
# ROC AUC Score:        0.7478
# ------------------------------------------------------------
# Epoch 2, Train Loss: 0.5663
# Validation Accuracy:  0.6775
# Precision:            0.6540
# Recall:               0.7506
# F1 Score:             0.6990
# ROC AUC Score:        0.7672
# ------------------------------------------------------------
# Epoch 3, Train Loss: 0.5481
# Validation Accuracy:  0.6969
# Precision:            0.6731
# Recall:               0.7627
# F1 Score:             0.7151
# ROC AUC Score:        0.7800
# ------------------------------------------------------------
# Epoch 4, Train Loss: 0.5339
# Validation Accuracy:  0.6920
# Precision:            0.6660
# Recall:               0.7676
# F1 Score:             0.7132
# ROC AUC Score:        0.7803
# ------------------------------------------------------------
# Epoch 5, Train Loss: 0.5252
# Validation Accuracy:  0.6932
# Precision:            0.6879
# Recall:               0.7046
# F1 Score:             0.6962
# ROC AUC Score:        0.7833
# ------------------------------------------------------------
# Epoch 6, Train Loss: 0.5131
# Validation Accuracy:  0.6896
# Precision:            0.6681
# Recall:               0.7506
# F1 Score:             0.7070
# ROC AUC Score:        0.7897
# ------------------------------------------------------------
# Epoch 7, Train Loss: 0.4933
# Validation Accuracy:  0.6957
# Precision:            0.6613
# Recall:               0.7990
# F1 Score:             0.7237
# ROC AUC Score:        0.7900
# ------------------------------------------------------------
# Epoch 8, Train Loss: 0.4867
# Validation Accuracy:  0.7271
# Precision:            0.7825
# Recall:               0.6271
# F1 Score:             0.6962
# ROC AUC Score:        0.7916
# ------------------------------------------------------------
# Epoch 9, Train Loss: 0.4824
# Validation Accuracy:  0.6824
# Precision:            0.6518
# Recall:               0.7797
# F1 Score:             0.7100
# ROC AUC Score:        0.7895
# ------------------------------------------------------------
# Epoch 10, Train Loss: 0.4633
# Validation Accuracy:  0.6848
# Precision:            0.6526
# Recall:               0.7869
# F1 Score:             0.7135
# ROC AUC Score:        0.7969
# ------------------------------------------------------------
# Epoch 11, Train Loss: 0.4671
# Validation Accuracy:  0.6860
# Precision:            0.6577
# Recall:               0.7724
# F1 Score:             0.7105
# ROC AUC Score:        0.7915
# ------------------------------------------------------------
# Epoch 12, Train Loss: 0.4477
# Validation Accuracy:  0.6860
# Precision:            0.7525
# Recall:               0.5521
# F1 Score:             0.6369
# ROC AUC Score:        0.7577
# ------------------------------------------------------------
# Epoch 13, Train Loss: 0.4660
# Validation Accuracy:  0.7295
# Precision:            0.7534
# Recall:               0.6804
# F1 Score:             0.7150
# ROC AUC Score:        0.7986
# ------------------------------------------------------------
# Epoch 14, Train Loss: 0.4322
# Validation Accuracy:  0.7017
# Precision:            0.7196
# Recall:               0.6586
# F1 Score:             0.6877
# ROC AUC Score:        0.7864
# ------------------------------------------------------------
# Epoch 15, Train Loss: 0.4001
# Validation Accuracy:  0.6872
# Precision:            0.6638
# Recall:               0.7554
# F1 Score:             0.7067
# ROC AUC Score:        0.7865
# ------------------------------------------------------------
# Epoch 16, Train Loss: 0.3877
# Validation Accuracy:  0.6860
# Precision:            0.6571
# Recall:               0.7748
# F1 Score:             0.7111
# ROC AUC Score:        0.7839
# ------------------------------------------------------------
# Epoch 17, Train Loss: 0.3867
# Validation Accuracy:  0.6920
# Precision:            0.6820
# Recall:               0.7167
# F1 Score:             0.6989
# ROC AUC Score:        0.7761
# ------------------------------------------------------------
# Epoch 18, Train Loss: 0.3749
# Validation Accuracy:  0.6884
# Precision:            0.6824
# Recall:               0.7022
# F1 Score:             0.6921
# ROC AUC Score:        0.7775
# ------------------------------------------------------------
# Epoch 19, Train Loss: 0.3753
# Validation Accuracy:  0.6896
# Precision:            0.6848
# Recall:               0.6998
# F1 Score:             0.6922
# ROC AUC Score:        0.7740
# ------------------------------------------------------------
# Epoch 20, Train Loss: 0.3467
# Validation Accuracy:  0.6800
# Precision:            0.6787
# Recall:               0.6804
# F1 Score:             0.6796
# ROC AUC Score:        0.7724
# ------------------------------------------------------------
# Epoch 21, Train Loss: 0.3256
# Validation Accuracy:  0.7017
# Precision:            0.6986
# Recall:               0.7070
# F1 Score:             0.7028
# ROC AUC Score:        0.7692
# ------------------------------------------------------------
# Epoch 22, Train Loss: 0.3372
# Validation Accuracy:  0.7053
# Precision:            0.7195
# Recall:               0.6707
# F1 Score:             0.6942
# ROC AUC Score:        0.7693
# ------------------------------------------------------------
# Epoch 23, Train Loss: 0.3107
# Validation Accuracy:  0.6957
# Precision:            0.6785
# Recall:               0.7409
# F1 Score:             0.7083
# ROC AUC Score:        0.7835
# ------------------------------------------------------------
# Epoch 24, Train Loss: 0.3123
# Validation Accuracy:  0.7005
# Precision:            0.6914
# Recall:               0.7215
# F1 Score:             0.7062
# ROC AUC Score:        0.7752
# ------------------------------------------------------------
# Epoch 25, Train Loss: 0.2862
# Validation Accuracy:  0.7053
# Precision:            0.6857
# Recall:               0.7554
# F1 Score:             0.7189
# ROC AUC Score:        0.7787
# ------------------------------------------------------------
# Epoch 26, Train Loss: 0.2677
# Validation Accuracy:  0.6969
# Precision:            0.6875
# Recall:               0.7191
# F1 Score:             0.7030
# ROC AUC Score:        0.7817
# ------------------------------------------------------------
# Epoch 27, Train Loss: 0.2819
# Validation Accuracy:  0.6993
# Precision:            0.7020
# Recall:               0.6901
# F1 Score:             0.6960
# ROC AUC Score:        0.7753
# ------------------------------------------------------------
# Epoch 28, Train Loss: 0.2560
# Validation Accuracy:  0.6739
# Precision:            0.6682
# Recall:               0.6877
# F1 Score:             0.6778
# ROC AUC Score:        0.7655
# ------------------------------------------------------------
# Epoch 29, Train Loss: 0.2543
# Validation Accuracy:  0.6715
# Precision:            0.6621
# Recall:               0.6973
# F1 Score:             0.6792
# ROC AUC Score:        0.7641
# ------------------------------------------------------------
# Epoch 30, Train Loss: 0.2454
# Validation Accuracy:  0.6848
# Precision:            0.6959
# Recall:               0.6538
# F1 Score:             0.6742
# ROC AUC Score:        0.7613
# ------------------------------------------------------------
# Epoch 31, Train Loss: 0.2504
# Validation Accuracy:  0.6981
# Precision:            0.7074
# Recall:               0.6731
# F1 Score:             0.6898
# ROC AUC Score:        0.7733
# ------------------------------------------------------------
# Epoch 32, Train Loss: 0.2412
# Validation Accuracy:  0.6944
# Precision:            0.7010
# Recall:               0.6755
# F1 Score:             0.6880
# ROC AUC Score:        0.7674
# ------------------------------------------------------------
# Epoch 33, Train Loss: 0.2442
# Validation Accuracy:  0.7186
# Precision:            0.7601
# Recall:               0.6368
# F1 Score:             0.6930
# ROC AUC Score:        0.7683
# ------------------------------------------------------------
# Epoch 34, Train Loss: 0.2269
# Validation Accuracy:  0.7041
# Precision:            0.7609
# Recall:               0.5932
# F1 Score:             0.6667
# ROC AUC Score:        0.7488
# ------------------------------------------------------------
# Epoch 35, Train Loss: 0.2172
# Validation Accuracy:  0.6655
# Precision:            0.6498
# Recall:               0.7143
# F1 Score:             0.6805
# ROC AUC Score:        0.7584
# ------------------------------------------------------------
# Epoch 36, Train Loss: 0.1987
# Validation Accuracy:  0.7053
# Precision:            0.7302
# Recall:               0.6489
# F1 Score:             0.6872
# ROC AUC Score:        0.7492
# ------------------------------------------------------------
# Epoch 37, Train Loss: 0.1978
# Validation Accuracy:  0.6908
# Precision:            0.6796
# Recall:               0.7191
# F1 Score:             0.6988
# ROC AUC Score:        0.7522
# ------------------------------------------------------------
# Epoch 38, Train Loss: 0.1863
# Validation Accuracy:  0.6824
# Precision:            0.6659
# Recall:               0.7288
# F1 Score:             0.6960
# ROC AUC Score:        0.7609
# ------------------------------------------------------------
# Epoch 39, Train Loss: 0.1847
# Validation Accuracy:  0.6679
# Precision:            0.6450
# Recall:               0.7433
# F1 Score:             0.6907
# ROC AUC Score:        0.7448
# ------------------------------------------------------------
# Epoch 40, Train Loss: 0.1834
# Validation Accuracy:  0.6884
# Precision:            0.6688
# Recall:               0.7433
# F1 Score:             0.7041
# ROC AUC Score:        0.7701
# ------------------------------------------------------------
# Epoch 41, Train Loss: 0.1758
# Validation Accuracy:  0.6884
# Precision:            0.6726
# Recall:               0.7312
# F1 Score:             0.7007
# ROC AUC Score:        0.7709
# ------------------------------------------------------------
# Epoch 42, Train Loss: 0.1750
# Validation Accuracy:  0.7017
# Precision:            0.6976
# Recall:               0.7094
# F1 Score:             0.7035
# ROC AUC Score:        0.7540
# ------------------------------------------------------------

# %%
def evaluate_on_test(model, test_loader):
    model.eval()
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    all_preds = []
    all_labels = []

    with torch.no_grad():
        for xb, yb in test_loader:
            xb = xb.to(device)
            yb = yb.to(device).unsqueeze(1)

            logits = model(xb)
            probs = torch.sigmoid(logits)
            all_preds.append(probs.cpu())
            all_labels.append(yb.cpu())

    # Convert tensors
    y_prob = torch.cat(all_preds).numpy()
    y_true = torch.cat(all_labels).numpy()
    y_pred = (y_prob > 0.5).astype(float)

    # Metrics
    from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix
    cm = confusion_matrix(y_true, y_pred, normalize='true')
    print("Test Accuracy:", accuracy_score(y_true, y_pred))
    print("Precision:", precision_score(y_true, y_pred, zero_division=0))
    print("Recall:", recall_score(y_true, y_pred, zero_division=0))
    print("F1 Score:", f1_score(y_true, y_pred, zero_division=0))
    print("ROC AUC:", roc_auc_score(y_true, y_prob))
    print("Confusion Matrix:\n", cm)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot(cmap='Blues', values_format=".2f")
    plt.grid(False)
    plt.show()

# %%
evaluate_on_test(GRU_model, test_loader)
# Out:
# Test Accuracy: 0.7958333333333333
# Precision: 0.710239651416122
# Recall: 0.8380462724935732
# F1 Score: 0.7688679245283019
# ROC AUC: 0.9034301433015635
# Confusion Matrix:
#  [[0.76707531 0.23292469]
#  [0.16195373 0.83804627]]
